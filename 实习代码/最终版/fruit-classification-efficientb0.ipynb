# %%
import os
import random
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
from matplotlib.ticker import MaxNLocator
from matplotlib.image import imread
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications import EfficientNetB0
# Out:
# 2025-07-17 01:41:29.386354: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752716489.585180      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752716489.648764      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_path = "/kaggle/input/fruit-classification-dataset/Fruit_dataset/train1"
val_path = "/kaggle/input/fruit-classification-dataset/Fruit_dataset/val1"

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

#创建训练集
train_dataset = image_dataset_from_directory(
    train_path,
    shuffle=True,
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    label_mode='categorical',
    seed=42
)

#创建验证集
val_dataset = image_dataset_from_directory(
    val_path,
    shuffle=False,
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    label_mode='categorical',
    seed=42
)

class_names = train_dataset.class_names

AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=AUTOTUNE)


print(f"Number of classes: {len(class_names)}")
print(f"Class names: {class_names}")
print(f"Training batches: {tf.data.experimental.cardinality(train_dataset)}")
print(f"Validation batches: {tf.data.experimental.cardinality(val_dataset)}")
# Out:
# Found 40000 files belonging to 100 classes.
# I0000 00:00:1752716536.503575      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 5000 files belonging to 100 classes.
# Number of classes: 100
# Class names: ['abiu', 'acai', 'acerola', 'ackee', 'ambarella', 'apple', 'apricot', 'avocado', 'banana', 'barbadine', 'barberry', 'betel_nut', 'bitter_gourd', 'black_berry', 'black_mullberry', 'brazil_nut', 'camu_camu', 'cashew', 'cempedak', 'chenet', 'cherimoya', 'chico', 'chokeberry', 'cluster_fig', 'coconut', 'corn_kernel', 'cranberry', 'cupuacu', 'custard_apple', 'damson', 'dewberry', 'dragonfruit', 'durian', 'eggplant', 'elderberry', 'emblic', 'feijoa', 'fig', 'finger_lime', 'gooseberry', 'goumi', 'grape', 'grapefruit', 'greengage', 'grenadilla', 'guava', 'hard_kiwi', 'hawthorn', 'hog_plum', 'horned_melon', 'indian_strawberry', 'jaboticaba', 'jackfruit', 'jalapeno', 'jamaica_cherry', 'jambul', 'jocote', 'jujube', 'kaffir_lime', 'kumquat', 'lablab', 'langsat', 'longan', 'mabolo', 'malay_apple', 'mandarine', 'mango', 'mangosteen', 'medlar', 'mock_strawberry', 'morinda', 'mountain_soursop', 'oil_palm', 'olive', 'otaheite_apple', 'papaya', 'passion_fruit', 'pawpaw', 'pea', 'pineapple', 'plumcot', 'pomegranate', 'prikly_pear', 'quince', 'rambutan', 'raspberry', 'redcurrant', 'rose_hip', 'rose_leaf_bramble', 'salak', 'santol', 'sapodilla', 'sea_buckthorn', 'strawberry_guava', 'sugar_apple', 'taxus_baccata', 'ugli_fruit', 'white_currant', 'yali_pear', 'yellow_plum']
# Training batches: 1250
# Validation batches: 157

# %%
#数据增强预设
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.15),
    layers.RandomContrast(0.1),
])

#导入预训练模型
base_model = EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(224,224,3)
)

#冻结基模型
base_model.trainable = False

#设计新模型
inputs = layers.Input(shape=(224,224,3))

#数据增强
x = data_augmentation(inputs)

#归一化
x = tf.keras.applications.efficientnet.preprocess_input(x)

#基模型
x = base_model(x, training=False)

#加入分类头
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(100, activation='softmax')(x)

model_3 = models.Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
#模型预设
model_3.compile(
    optimizer=optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

#回调设置
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-7
)


print("Training top layers only")
history_3_ENB0 = model_3.fit(
    train_dataset,
    epochs=100,
    validation_data=val_dataset,
    callbacks=[early_stopping, reduce_lr]
)

#保存模型
model_3.save('/kaggle/working/tansfer_model')
# Out:
# Training top layers only
# Epoch 1/100
# E0000 00:00:1752716576.882756      35 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_1_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1752716579.648314      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 71ms/step - accuracy: 0.0962 - loss: 4.1284 - val_accuracy: 0.5220 - val_loss: 2.0170 - learning_rate: 1.0000e-04
# Epoch 2/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.3699 - loss: 2.4573 - val_accuracy: 0.5978 - val_loss: 1.5532 - learning_rate: 1.0000e-04
# Epoch 3/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.4543 - loss: 2.0331 - val_accuracy: 0.6362 - val_loss: 1.3541 - learning_rate: 1.0000e-04
# Epoch 4/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.5038 - loss: 1.8155 - val_accuracy: 0.6564 - val_loss: 1.2433 - learning_rate: 1.0000e-04
# Epoch 5/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.5344 - loss: 1.6746 - val_accuracy: 0.6720 - val_loss: 1.1656 - learning_rate: 1.0000e-04
# Epoch 6/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.5651 - loss: 1.5502 - val_accuracy: 0.6880 - val_loss: 1.0976 - learning_rate: 1.0000e-04
# Epoch 7/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.5804 - loss: 1.4883 - val_accuracy: 0.6986 - val_loss: 1.0585 - learning_rate: 1.0000e-04
# Epoch 8/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.6000 - loss: 1.4105 - val_accuracy: 0.7086 - val_loss: 1.0213 - learning_rate: 1.0000e-04
# Epoch 9/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.6121 - loss: 1.3692 - val_accuracy: 0.7186 - val_loss: 0.9860 - learning_rate: 1.0000e-04
# Epoch 10/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.6261 - loss: 1.3126 - val_accuracy: 0.7262 - val_loss: 0.9595 - learning_rate: 1.0000e-04
# Epoch 11/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.6372 - loss: 1.2647 - val_accuracy: 0.7312 - val_loss: 0.9362 - learning_rate: 1.0000e-04
# Epoch 12/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.6468 - loss: 1.2284 - val_accuracy: 0.7372 - val_loss: 0.9184 - learning_rate: 1.0000e-04
# Epoch 13/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.6526 - loss: 1.1929 - val_accuracy: 0.7388 - val_loss: 0.8974 - learning_rate: 1.0000e-04
# Epoch 14/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.6615 - loss: 1.1605 - val_accuracy: 0.7444 - val_loss: 0.8888 - learning_rate: 1.0000e-04
# Epoch 15/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.6717 - loss: 1.1276 - val_accuracy: 0.7494 - val_loss: 0.8712 - learning_rate: 1.0000e-04
# Epoch 16/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.6778 - loss: 1.1106 - val_accuracy: 0.7476 - val_loss: 0.8636 - learning_rate: 1.0000e-04
# Epoch 17/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.6800 - loss: 1.0856 - val_accuracy: 0.7548 - val_loss: 0.8465 - learning_rate: 1.0000e-04
# Epoch 18/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.6930 - loss: 1.0494 - val_accuracy: 0.7556 - val_loss: 0.8392 - learning_rate: 1.0000e-04
# Epoch 19/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 56ms/step - accuracy: 0.6919 - loss: 1.0455 - val_accuracy: 0.7578 - val_loss: 0.8310 - learning_rate: 1.0000e-04
# Epoch 20/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.6967 - loss: 1.0279 - val_accuracy: 0.7584 - val_loss: 0.8233 - learning_rate: 1.0000e-04
# Epoch 21/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7058 - loss: 1.0017 - val_accuracy: 0.7608 - val_loss: 0.8211 - learning_rate: 1.0000e-04
# Epoch 22/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7016 - loss: 0.9975 - val_accuracy: 0.7650 - val_loss: 0.8083 - learning_rate: 1.0000e-04
# Epoch 23/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7111 - loss: 0.9721 - val_accuracy: 0.7618 - val_loss: 0.8043 - learning_rate: 1.0000e-04
# Epoch 24/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 71s 57ms/step - accuracy: 0.7095 - loss: 0.9780 - val_accuracy: 0.7654 - val_loss: 0.7968 - learning_rate: 1.0000e-04
# Epoch 25/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7161 - loss: 0.9583 - val_accuracy: 0.7636 - val_loss: 0.7964 - learning_rate: 1.0000e-04
# Epoch 26/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 56ms/step - accuracy: 0.7210 - loss: 0.9383 - val_accuracy: 0.7664 - val_loss: 0.7928 - learning_rate: 1.0000e-04
# Epoch 27/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7226 - loss: 0.9188 - val_accuracy: 0.7688 - val_loss: 0.7846 - learning_rate: 1.0000e-04
# Epoch 28/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7275 - loss: 0.9083 - val_accuracy: 0.7668 - val_loss: 0.7787 - learning_rate: 1.0000e-04
# Epoch 29/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7261 - loss: 0.8989 - val_accuracy: 0.7676 - val_loss: 0.7790 - learning_rate: 1.0000e-04
# Epoch 30/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7303 - loss: 0.8920 - val_accuracy: 0.7686 - val_loss: 0.7721 - learning_rate: 1.0000e-04
# Epoch 31/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7334 - loss: 0.8823 - val_accuracy: 0.7630 - val_loss: 0.7680 - learning_rate: 1.0000e-04
# Epoch 32/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7350 - loss: 0.8734 - val_accuracy: 0.7694 - val_loss: 0.7641 - learning_rate: 1.0000e-04
# Epoch 33/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7403 - loss: 0.8609 - val_accuracy: 0.7716 - val_loss: 0.7621 - learning_rate: 1.0000e-04
# Epoch 34/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7428 - loss: 0.8544 - val_accuracy: 0.7736 - val_loss: 0.7612 - learning_rate: 1.0000e-04
# Epoch 35/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7402 - loss: 0.8451 - val_accuracy: 0.7772 - val_loss: 0.7566 - learning_rate: 1.0000e-04
# Epoch 36/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7444 - loss: 0.8439 - val_accuracy: 0.7778 - val_loss: 0.7552 - learning_rate: 1.0000e-04
# Epoch 37/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 71s 57ms/step - accuracy: 0.7495 - loss: 0.8263 - val_accuracy: 0.7776 - val_loss: 0.7550 - learning_rate: 1.0000e-04
# Epoch 38/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7489 - loss: 0.8138 - val_accuracy: 0.7784 - val_loss: 0.7506 - learning_rate: 1.0000e-04
# Epoch 39/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7483 - loss: 0.8155 - val_accuracy: 0.7786 - val_loss: 0.7492 - learning_rate: 1.0000e-04
# Epoch 40/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7575 - loss: 0.8021 - val_accuracy: 0.7800 - val_loss: 0.7484 - learning_rate: 1.0000e-04
# Epoch 41/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7487 - loss: 0.8032 - val_accuracy: 0.7792 - val_loss: 0.7505 - learning_rate: 1.0000e-04
# Epoch 42/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7554 - loss: 0.7906 - val_accuracy: 0.7810 - val_loss: 0.7414 - learning_rate: 1.0000e-04
# Epoch 43/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7596 - loss: 0.7879 - val_accuracy: 0.7804 - val_loss: 0.7411 - learning_rate: 1.0000e-04
# Epoch 44/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7604 - loss: 0.7690 - val_accuracy: 0.7836 - val_loss: 0.7429 - learning_rate: 1.0000e-04
# Epoch 45/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7641 - loss: 0.7687 - val_accuracy: 0.7850 - val_loss: 0.7352 - learning_rate: 1.0000e-04
# Epoch 46/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7655 - loss: 0.7571 - val_accuracy: 0.7864 - val_loss: 0.7335 - learning_rate: 1.0000e-04
# Epoch 47/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7666 - loss: 0.7445 - val_accuracy: 0.7852 - val_loss: 0.7357 - learning_rate: 1.0000e-04
# Epoch 48/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7702 - loss: 0.7487 - val_accuracy: 0.7834 - val_loss: 0.7360 - learning_rate: 1.0000e-04
# Epoch 49/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7708 - loss: 0.7401 - val_accuracy: 0.7878 - val_loss: 0.7327 - learning_rate: 1.0000e-04
# Epoch 50/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7697 - loss: 0.7419 - val_accuracy: 0.7846 - val_loss: 0.7380 - learning_rate: 1.0000e-04
# Epoch 51/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7716 - loss: 0.7338 - val_accuracy: 0.7832 - val_loss: 0.7308 - learning_rate: 1.0000e-04
# Epoch 52/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7755 - loss: 0.7236 - val_accuracy: 0.7848 - val_loss: 0.7349 - learning_rate: 1.0000e-04
# Epoch 53/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7751 - loss: 0.7281 - val_accuracy: 0.7850 - val_loss: 0.7320 - learning_rate: 1.0000e-04
# Epoch 54/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7744 - loss: 0.7199 - val_accuracy: 0.7874 - val_loss: 0.7333 - learning_rate: 1.0000e-04
# Epoch 55/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7795 - loss: 0.6973 - val_accuracy: 0.7898 - val_loss: 0.7254 - learning_rate: 2.0000e-05
# Epoch 56/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7840 - loss: 0.6932 - val_accuracy: 0.7880 - val_loss: 0.7255 - learning_rate: 2.0000e-05
# Epoch 57/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7871 - loss: 0.6807 - val_accuracy: 0.7848 - val_loss: 0.7258 - learning_rate: 2.0000e-05
# Epoch 58/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7864 - loss: 0.6849 - val_accuracy: 0.7884 - val_loss: 0.7243 - learning_rate: 2.0000e-05
# Epoch 59/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7882 - loss: 0.6819 - val_accuracy: 0.7882 - val_loss: 0.7241 - learning_rate: 2.0000e-05
# Epoch 60/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7882 - loss: 0.6703 - val_accuracy: 0.7886 - val_loss: 0.7236 - learning_rate: 2.0000e-05
# Epoch 61/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7908 - loss: 0.6721 - val_accuracy: 0.7882 - val_loss: 0.7253 - learning_rate: 2.0000e-05
# Epoch 62/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7930 - loss: 0.6643 - val_accuracy: 0.7866 - val_loss: 0.7246 - learning_rate: 2.0000e-05
# Epoch 63/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7932 - loss: 0.6633 - val_accuracy: 0.7868 - val_loss: 0.7200 - learning_rate: 2.0000e-05
# Epoch 64/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7920 - loss: 0.6689 - val_accuracy: 0.7892 - val_loss: 0.7198 - learning_rate: 2.0000e-05
# Epoch 65/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7899 - loss: 0.6640 - val_accuracy: 0.7890 - val_loss: 0.7221 - learning_rate: 2.0000e-05
# Epoch 66/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7934 - loss: 0.6623 - val_accuracy: 0.7884 - val_loss: 0.7219 - learning_rate: 2.0000e-05
# Epoch 67/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7921 - loss: 0.6587 - val_accuracy: 0.7882 - val_loss: 0.7210 - learning_rate: 2.0000e-05
# Epoch 68/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7977 - loss: 0.6568 - val_accuracy: 0.7894 - val_loss: 0.7204 - learning_rate: 4.0000e-06
# Epoch 69/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7955 - loss: 0.6477 - val_accuracy: 0.7878 - val_loss: 0.7214 - learning_rate: 4.0000e-06
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_35/492574275.py in <cell line: 0>()
#      30
#      31 #保存模型
# ---> 32 model_3.save('/kaggle/working/tansfer_model')
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in save_model(model, filepath, overwrite, zipped, **kwargs)
#     112             model, filepath, overwrite, include_optimizer
#     113         )
# --> 114     raise ValueError(
#     115         "Invalid filepath extension for saving. "
#     116         "Please add either a `.keras` extension for the native Keras "
#
# ValueError: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=/kaggle/working/tansfer_model.

# %%
#解冻微调模型
def unfreeze_model(model):
    for layer in model.layers:
        if layer.__class__.__name__ == 'BatchNormalization':
            layer.trainable = False

    # Find the EfficientNetB0 layer by class name
    base_model = None
    for layer in model.layers:
        if layer.__class__.__name__ == 'Functional': # EfficientNetB0 base model is a Functional API model
            base_model = layer
            break


    if base_model is None:
        print("Error: EfficientNetB0 layer not found in the model.")
        return

    #解冻30层基模型
    for layer in base_model.layers[-30:]:
        if layer.__class__.__name__ != 'BatchNormalization':
            layer.trainable = True


    model.compile(
        optimizer=optimizers.Adam(learning_rate=1e-5),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

print("Fine-Tuning Top Layers of Model_3")
unfreeze_model(model_3)


history_4_fine_ENB0 = model_3.fit(
    train_dataset,
    epochs=100,
    validation_data=val_dataset,
    callbacks=[early_stopping, reduce_lr]
)

#保存模型
model_3.save('/kaggle/working/transfer_model2.h5')
# Out:
# Fine-Tuning Top Layers of Model_3
# Epoch 1/100
# E0000 00:00:1752721802.609000      35 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_1_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 99s 65ms/step - accuracy: 0.8043 - loss: 0.6165 - val_accuracy: 0.7954 - val_loss: 0.7158 - learning_rate: 1.0000e-05
# Epoch 2/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.8054 - loss: 0.6203 - val_accuracy: 0.7960 - val_loss: 0.7083 - learning_rate: 1.0000e-05
# Epoch 3/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.8058 - loss: 0.6044 - val_accuracy: 0.7972 - val_loss: 0.7057 - learning_rate: 1.0000e-05
# Epoch 4/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8137 - loss: 0.5846 - val_accuracy: 0.7964 - val_loss: 0.7071 - learning_rate: 1.0000e-05
# Epoch 5/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8127 - loss: 0.5833 - val_accuracy: 0.7978 - val_loss: 0.7053 - learning_rate: 1.0000e-05
# Epoch 6/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.8181 - loss: 0.5730 - val_accuracy: 0.7984 - val_loss: 0.7059 - learning_rate: 1.0000e-05
# Epoch 7/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8129 - loss: 0.5749 - val_accuracy: 0.7974 - val_loss: 0.7032 - learning_rate: 1.0000e-05
# Epoch 8/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.8223 - loss: 0.5568 - val_accuracy: 0.7968 - val_loss: 0.6986 - learning_rate: 1.0000e-05
# Epoch 9/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8219 - loss: 0.5546 - val_accuracy: 0.8008 - val_loss: 0.6987 - learning_rate: 1.0000e-05
# Epoch 10/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8198 - loss: 0.5527 - val_accuracy: 0.8004 - val_loss: 0.6962 - learning_rate: 1.0000e-05
# Epoch 11/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8212 - loss: 0.5565 - val_accuracy: 0.8016 - val_loss: 0.6916 - learning_rate: 1.0000e-05
# Epoch 12/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8230 - loss: 0.5475 - val_accuracy: 0.8042 - val_loss: 0.6853 - learning_rate: 1.0000e-05
# Epoch 13/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8223 - loss: 0.5473 - val_accuracy: 0.8038 - val_loss: 0.6870 - learning_rate: 1.0000e-05
# Epoch 14/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8245 - loss: 0.5400 - val_accuracy: 0.8066 - val_loss: 0.6836 - learning_rate: 1.0000e-05
# Epoch 15/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8301 - loss: 0.5336 - val_accuracy: 0.8056 - val_loss: 0.6824 - learning_rate: 1.0000e-05
# Epoch 16/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.8287 - loss: 0.5331 - val_accuracy: 0.8066 - val_loss: 0.6822 - learning_rate: 1.0000e-05
# Epoch 17/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8353 - loss: 0.5095 - val_accuracy: 0.8070 - val_loss: 0.6834 - learning_rate: 1.0000e-05
# Epoch 18/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8286 - loss: 0.5212 - val_accuracy: 0.8072 - val_loss: 0.6844 - learning_rate: 1.0000e-05
# Epoch 19/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.8340 - loss: 0.5208 - val_accuracy: 0.8050 - val_loss: 0.6787 - learning_rate: 1.0000e-05
# Epoch 20/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8315 - loss: 0.5125 - val_accuracy: 0.8074 - val_loss: 0.6813 - learning_rate: 1.0000e-05
# Epoch 21/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.8364 - loss: 0.5034 - val_accuracy: 0.8088 - val_loss: 0.6829 - learning_rate: 1.0000e-05
# Epoch 22/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8358 - loss: 0.4995 - val_accuracy: 0.8074 - val_loss: 0.6815 - learning_rate: 1.0000e-05
# Epoch 23/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.8393 - loss: 0.4975 - val_accuracy: 0.8092 - val_loss: 0.6792 - learning_rate: 2.0000e-06
# Epoch 24/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.8366 - loss: 0.4987 - val_accuracy: 0.8104 - val_loss: 0.6778 - learning_rate: 2.0000e-06
# Epoch 25/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8436 - loss: 0.4849 - val_accuracy: 0.8102 - val_loss: 0.6786 - learning_rate: 2.0000e-06
# Epoch 26/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8426 - loss: 0.4808 - val_accuracy: 0.8102 - val_loss: 0.6773 - learning_rate: 2.0000e-06
# Epoch 27/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8428 - loss: 0.4787 - val_accuracy: 0.8098 - val_loss: 0.6779 - learning_rate: 2.0000e-06
# Epoch 28/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8437 - loss: 0.4803 - val_accuracy: 0.8092 - val_loss: 0.6793 - learning_rate: 2.0000e-06
# Epoch 29/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8403 - loss: 0.4802 - val_accuracy: 0.8106 - val_loss: 0.6773 - learning_rate: 2.0000e-06
# Epoch 30/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.8430 - loss: 0.4827 - val_accuracy: 0.8102 - val_loss: 0.6775 - learning_rate: 4.0000e-07
# Epoch 31/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.8433 - loss: 0.4801 - val_accuracy: 0.8104 - val_loss: 0.6774 - learning_rate: 4.0000e-07
