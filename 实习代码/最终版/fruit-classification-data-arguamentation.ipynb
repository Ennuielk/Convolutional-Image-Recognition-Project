# %%
import os
import random
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
from matplotlib.ticker import MaxNLocator
from matplotlib.image import imread
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications import EfficientNetB0
# Out:
# 2025-07-18 06:28:16.591358: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752820096.789093      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752820096.853905      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_path = "/kaggle/input/fruit-classification-dataset/Fruit_dataset/train1"
val_path = "/kaggle/input/fruit-classification-dataset/Fruit_dataset/val1"

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

#创建训练集
train_dataset = image_dataset_from_directory(
    train_path,
    shuffle=True,
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    label_mode='categorical',
    seed=42
)

#创建验证集
val_dataset = image_dataset_from_directory(
    val_path,
    shuffle=False,
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    label_mode='categorical',
    seed=42
)

class_names = train_dataset.class_names

AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=AUTOTUNE)


print(f"Number of classes: {len(class_names)}")
print(f"Class names: {class_names}")
print(f"Training batches: {tf.data.experimental.cardinality(train_dataset)}")
print(f"Validation batches: {tf.data.experimental.cardinality(val_dataset)}")
# Out:
# Found 40000 files belonging to 100 classes.
# I0000 00:00:1752820143.377116      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 5000 files belonging to 100 classes.
# Number of classes: 100
# Class names: ['abiu', 'acai', 'acerola', 'ackee', 'ambarella', 'apple', 'apricot', 'avocado', 'banana', 'barbadine', 'barberry', 'betel_nut', 'bitter_gourd', 'black_berry', 'black_mullberry', 'brazil_nut', 'camu_camu', 'cashew', 'cempedak', 'chenet', 'cherimoya', 'chico', 'chokeberry', 'cluster_fig', 'coconut', 'corn_kernel', 'cranberry', 'cupuacu', 'custard_apple', 'damson', 'dewberry', 'dragonfruit', 'durian', 'eggplant', 'elderberry', 'emblic', 'feijoa', 'fig', 'finger_lime', 'gooseberry', 'goumi', 'grape', 'grapefruit', 'greengage', 'grenadilla', 'guava', 'hard_kiwi', 'hawthorn', 'hog_plum', 'horned_melon', 'indian_strawberry', 'jaboticaba', 'jackfruit', 'jalapeno', 'jamaica_cherry', 'jambul', 'jocote', 'jujube', 'kaffir_lime', 'kumquat', 'lablab', 'langsat', 'longan', 'mabolo', 'malay_apple', 'mandarine', 'mango', 'mangosteen', 'medlar', 'mock_strawberry', 'morinda', 'mountain_soursop', 'oil_palm', 'olive', 'otaheite_apple', 'papaya', 'passion_fruit', 'pawpaw', 'pea', 'pineapple', 'plumcot', 'pomegranate', 'prikly_pear', 'quince', 'rambutan', 'raspberry', 'redcurrant', 'rose_hip', 'rose_leaf_bramble', 'salak', 'santol', 'sapodilla', 'sea_buckthorn', 'strawberry_guava', 'sugar_apple', 'taxus_baccata', 'ugli_fruit', 'white_currant', 'yali_pear', 'yellow_plum']
# Training batches: 1250
# Validation batches: 157

# %%
#数据增强预设
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

inputs = layers.Input(shape=(224,224,3))

#数据增强
x = data_augmentation(inputs)

#归一化
x = layers.Rescaling(1./255)(x)

#卷积基
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

#分类头
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(100, activation='softmax')(x)

model_2 = models.Model(inputs=inputs, outputs=outputs)

# %%
#模型预设
model_2.compile(
    optimizer=optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

#回调设置
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-7
)

#训练
history_2 = model_2.fit(
    train_dataset,
    epochs=100,
    validation_data=val_dataset,
    callbacks=[early_stopping, reduce_lr]
)

#保存模型
model_2.save('/kaggle/working/data_augmentation.h5')
# Out:
# Epoch 1/100
# I0000 00:00:1752820168.007058      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 126s 93ms/step - accuracy: 0.0127 - loss: 4.7856 - val_accuracy: 0.0308 - val_loss: 4.4957 - learning_rate: 1.0000e-04
# Epoch 2/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.0207 - loss: 4.5471 - val_accuracy: 0.0316 - val_loss: 4.4222 - learning_rate: 1.0000e-04
# Epoch 3/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.0251 - loss: 4.4984 - val_accuracy: 0.0384 - val_loss: 4.3335 - learning_rate: 1.0000e-04
# Epoch 4/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 87ms/step - accuracy: 0.0246 - loss: 4.4612 - val_accuracy: 0.0508 - val_loss: 4.2951 - learning_rate: 1.0000e-04
# Epoch 5/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.0291 - loss: 4.4055 - val_accuracy: 0.0500 - val_loss: 4.2682 - learning_rate: 1.0000e-04
# Epoch 6/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.0353 - loss: 4.3429 - val_accuracy: 0.0712 - val_loss: 4.1476 - learning_rate: 1.0000e-04
# Epoch 7/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.0442 - loss: 4.2660 - val_accuracy: 0.0756 - val_loss: 4.0821 - learning_rate: 1.0000e-04
# Epoch 8/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.0519 - loss: 4.1898 - val_accuracy: 0.0864 - val_loss: 4.0094 - learning_rate: 1.0000e-04
# Epoch 9/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.0582 - loss: 4.1114 - val_accuracy: 0.0934 - val_loss: 3.9194 - learning_rate: 1.0000e-04
# Epoch 10/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.0659 - loss: 4.0264 - val_accuracy: 0.1082 - val_loss: 3.8478 - learning_rate: 1.0000e-04
# Epoch 11/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.0717 - loss: 3.9540 - val_accuracy: 0.1158 - val_loss: 3.7510 - learning_rate: 1.0000e-04
# Epoch 12/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.0866 - loss: 3.8598 - val_accuracy: 0.1446 - val_loss: 3.6323 - learning_rate: 1.0000e-04
# Epoch 13/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.0969 - loss: 3.7667 - val_accuracy: 0.1484 - val_loss: 3.6042 - learning_rate: 1.0000e-04
# Epoch 14/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.1046 - loss: 3.7103 - val_accuracy: 0.1606 - val_loss: 3.4558 - learning_rate: 1.0000e-04
# Epoch 15/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.1128 - loss: 3.6355 - val_accuracy: 0.1758 - val_loss: 3.3515 - learning_rate: 1.0000e-04
# Epoch 16/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 112s 89ms/step - accuracy: 0.1233 - loss: 3.5602 - val_accuracy: 0.1798 - val_loss: 3.3620 - learning_rate: 1.0000e-04
# Epoch 17/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.1360 - loss: 3.5053 - val_accuracy: 0.2026 - val_loss: 3.1959 - learning_rate: 1.0000e-04
# Epoch 18/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 87ms/step - accuracy: 0.1474 - loss: 3.4239 - val_accuracy: 0.2094 - val_loss: 3.2250 - learning_rate: 1.0000e-04
# Epoch 19/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.1540 - loss: 3.3584 - val_accuracy: 0.2248 - val_loss: 3.1304 - learning_rate: 1.0000e-04
# Epoch 20/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.1655 - loss: 3.2907 - val_accuracy: 0.2424 - val_loss: 3.0417 - learning_rate: 1.0000e-04
# Epoch 21/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.1777 - loss: 3.2410 - val_accuracy: 0.2368 - val_loss: 3.0287 - learning_rate: 1.0000e-04
# Epoch 22/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 87ms/step - accuracy: 0.1902 - loss: 3.1752 - val_accuracy: 0.2392 - val_loss: 3.1308 - learning_rate: 1.0000e-04
# Epoch 23/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.1932 - loss: 3.1277 - val_accuracy: 0.2496 - val_loss: 3.0288 - learning_rate: 1.0000e-04
# Epoch 24/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2052 - loss: 3.0822 - val_accuracy: 0.2766 - val_loss: 2.8946 - learning_rate: 1.0000e-04
# Epoch 25/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2177 - loss: 3.0303 - val_accuracy: 0.2776 - val_loss: 2.8788 - learning_rate: 1.0000e-04
# Epoch 26/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2283 - loss: 2.9721 - val_accuracy: 0.2790 - val_loss: 2.8734 - learning_rate: 1.0000e-04
# Epoch 27/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2362 - loss: 2.9206 - val_accuracy: 0.2846 - val_loss: 2.8395 - learning_rate: 1.0000e-04
# Epoch 28/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.2427 - loss: 2.8881 - val_accuracy: 0.2770 - val_loss: 3.0151 - learning_rate: 1.0000e-04
# Epoch 29/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2581 - loss: 2.8284 - val_accuracy: 0.3282 - val_loss: 2.6456 - learning_rate: 1.0000e-04
# Epoch 30/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2615 - loss: 2.8076 - val_accuracy: 0.3040 - val_loss: 2.8618 - learning_rate: 1.0000e-04
# Epoch 31/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2732 - loss: 2.7607 - val_accuracy: 0.3458 - val_loss: 2.6202 - learning_rate: 1.0000e-04
# Epoch 32/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2790 - loss: 2.7059 - val_accuracy: 0.3188 - val_loss: 2.7001 - learning_rate: 1.0000e-04
# Epoch 33/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2906 - loss: 2.6651 - val_accuracy: 0.3362 - val_loss: 2.6027 - learning_rate: 1.0000e-04
# Epoch 34/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.2952 - loss: 2.6326 - val_accuracy: 0.3492 - val_loss: 2.5926 - learning_rate: 1.0000e-04
# Epoch 35/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.3025 - loss: 2.6125 - val_accuracy: 0.3208 - val_loss: 2.8109 - learning_rate: 1.0000e-04
# Epoch 36/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3124 - loss: 2.5722 - val_accuracy: 0.3582 - val_loss: 2.5401 - learning_rate: 1.0000e-04
# Epoch 37/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3202 - loss: 2.5208 - val_accuracy: 0.3656 - val_loss: 2.4875 - learning_rate: 1.0000e-04
# Epoch 38/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 87ms/step - accuracy: 0.3311 - loss: 2.4890 - val_accuracy: 0.3490 - val_loss: 2.5654 - learning_rate: 1.0000e-04
# Epoch 39/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3385 - loss: 2.4580 - val_accuracy: 0.3778 - val_loss: 2.4036 - learning_rate: 1.0000e-04
# Epoch 40/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3464 - loss: 2.4275 - val_accuracy: 0.3696 - val_loss: 2.4888 - learning_rate: 1.0000e-04
# Epoch 41/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3485 - loss: 2.3920 - val_accuracy: 0.3706 - val_loss: 2.4617 - learning_rate: 1.0000e-04
# Epoch 42/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.3591 - loss: 2.3692 - val_accuracy: 0.4004 - val_loss: 2.4673 - learning_rate: 1.0000e-04
# Epoch 43/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.3751 - loss: 2.2876 - val_accuracy: 0.4100 - val_loss: 2.3143 - learning_rate: 2.0000e-05
# Epoch 44/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3926 - loss: 2.2295 - val_accuracy: 0.4118 - val_loss: 2.3047 - learning_rate: 2.0000e-05
# Epoch 45/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3883 - loss: 2.2233 - val_accuracy: 0.4068 - val_loss: 2.3225 - learning_rate: 2.0000e-05
# Epoch 46/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.4019 - loss: 2.1861 - val_accuracy: 0.4076 - val_loss: 2.3671 - learning_rate: 2.0000e-05
# Epoch 47/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3951 - loss: 2.1820 - val_accuracy: 0.4198 - val_loss: 2.2836 - learning_rate: 2.0000e-05
# Epoch 48/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.4047 - loss: 2.1570 - val_accuracy: 0.4198 - val_loss: 2.3199 - learning_rate: 2.0000e-05
# Epoch 49/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.4017 - loss: 2.1650 - val_accuracy: 0.4142 - val_loss: 2.3090 - learning_rate: 2.0000e-05
# Epoch 50/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.4130 - loss: 2.1214 - val_accuracy: 0.4204 - val_loss: 2.3088 - learning_rate: 2.0000e-05
# Epoch 51/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.4088 - loss: 2.1243 - val_accuracy: 0.4304 - val_loss: 2.2316 - learning_rate: 4.0000e-06
# Epoch 52/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.4130 - loss: 2.1070 - val_accuracy: 0.4314 - val_loss: 2.2385 - learning_rate: 4.0000e-06
# Epoch 53/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.4202 - loss: 2.1060 - val_accuracy: 0.4348 - val_loss: 2.2182 - learning_rate: 4.0000e-06
# Epoch 54/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.4178 - loss: 2.0901 - val_accuracy: 0.4336 - val_loss: 2.2433 - learning_rate: 4.0000e-06
# Epoch 55/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.4181 - loss: 2.0891 - val_accuracy: 0.4348 - val_loss: 2.2270 - learning_rate: 4.0000e-06
# Epoch 56/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.4185 - loss: 2.0901 - val_accuracy: 0.4322 - val_loss: 2.2497 - learning_rate: 4.0000e-06
# Epoch 57/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 87ms/step - accuracy: 0.4219 - loss: 2.0866 - val_accuracy: 0.4356 - val_loss: 2.2228 - learning_rate: 8.0000e-07
# Epoch 58/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 88ms/step - accuracy: 0.4221 - loss: 2.0914 - val_accuracy: 0.4334 - val_loss: 2.2246 - learning_rate: 8.0000e-07
