# %%
import os
import random
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
from matplotlib.ticker import MaxNLocator
from matplotlib.image import imread
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications import EfficientNetB0
# Out:
# 2025-07-17 06:30:24.786080: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752733824.971041      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752733825.028716      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_path = "/kaggle/input/fruit-classification-dataset/Fruit_dataset/train1"
val_path = "/kaggle/input/fruit-classification-dataset/Fruit_dataset/val1"

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

#创建训练集
train_dataset = image_dataset_from_directory(
    train_path,
    shuffle=True,
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    label_mode='categorical',
    seed=42
)

#创建验证集
val_dataset = image_dataset_from_directory(
    val_path,
    shuffle=False,
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    label_mode='categorical',
    seed=42
)

class_names = train_dataset.class_names

AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=AUTOTUNE)


#数据信息
print(f"Number of classes: {len(class_names)}")
print(f"Class names: {class_names}")
print(f"Training batches: {tf.data.experimental.cardinality(train_dataset)}")
print(f"Validation batches: {tf.data.experimental.cardinality(val_dataset)}")
# Out:
# Found 40000 files belonging to 100 classes.
# I0000 00:00:1752733907.464626      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 5000 files belonging to 100 classes.
# Number of classes: 100
# Class names: ['abiu', 'acai', 'acerola', 'ackee', 'ambarella', 'apple', 'apricot', 'avocado', 'banana', 'barbadine', 'barberry', 'betel_nut', 'bitter_gourd', 'black_berry', 'black_mullberry', 'brazil_nut', 'camu_camu', 'cashew', 'cempedak', 'chenet', 'cherimoya', 'chico', 'chokeberry', 'cluster_fig', 'coconut', 'corn_kernel', 'cranberry', 'cupuacu', 'custard_apple', 'damson', 'dewberry', 'dragonfruit', 'durian', 'eggplant', 'elderberry', 'emblic', 'feijoa', 'fig', 'finger_lime', 'gooseberry', 'goumi', 'grape', 'grapefruit', 'greengage', 'grenadilla', 'guava', 'hard_kiwi', 'hawthorn', 'hog_plum', 'horned_melon', 'indian_strawberry', 'jaboticaba', 'jackfruit', 'jalapeno', 'jamaica_cherry', 'jambul', 'jocote', 'jujube', 'kaffir_lime', 'kumquat', 'lablab', 'langsat', 'longan', 'mabolo', 'malay_apple', 'mandarine', 'mango', 'mangosteen', 'medlar', 'mock_strawberry', 'morinda', 'mountain_soursop', 'oil_palm', 'olive', 'otaheite_apple', 'papaya', 'passion_fruit', 'pawpaw', 'pea', 'pineapple', 'plumcot', 'pomegranate', 'prikly_pear', 'quince', 'rambutan', 'raspberry', 'redcurrant', 'rose_hip', 'rose_leaf_bramble', 'salak', 'santol', 'sapodilla', 'sea_buckthorn', 'strawberry_guava', 'sugar_apple', 'taxus_baccata', 'ugli_fruit', 'white_currant', 'yali_pear', 'yellow_plum']
# Training batches: 1250
# Validation batches: 157

# %%
inputs = layers.Input(shape=(224,224,3))

#归一化
x = layers.Rescaling(1./255)(inputs)

#卷积基
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

#分类头
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(100, activation='softmax')(x)

model_1 = models.Model(inputs=inputs, outputs=outputs)

# %%
#模型预设
model_1.compile(
    optimizer=optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

#回调设置
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-7
)

#训练
history = model_1.fit(
    train_dataset,
    epochs=100,
    validation_data=val_dataset,
    callbacks=[early_stopping, reduce_lr]
)

#保存模型
model_1.save('/kaggle/working/CNN_model.h5')
# Out:
# Epoch 1/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 73s 51ms/step - accuracy: 0.0130 - loss: 4.8056 - val_accuracy: 0.0228 - val_loss: 4.5688 - learning_rate: 1.0000e-04
# Epoch 2/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.0179 - loss: 4.5816 - val_accuracy: 0.0236 - val_loss: 4.5365 - learning_rate: 1.0000e-04
# Epoch 3/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.0218 - loss: 4.5466 - val_accuracy: 0.0408 - val_loss: 4.3712 - learning_rate: 1.0000e-04
# Epoch 4/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.0295 - loss: 4.4605 - val_accuracy: 0.0660 - val_loss: 4.2831 - learning_rate: 1.0000e-04
# Epoch 5/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.0397 - loss: 4.3660 - val_accuracy: 0.0710 - val_loss: 4.1559 - learning_rate: 1.0000e-04
# Epoch 6/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.0482 - loss: 4.2779 - val_accuracy: 0.0938 - val_loss: 4.0944 - learning_rate: 1.0000e-04
# Epoch 7/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 36ms/step - accuracy: 0.0570 - loss: 4.1984 - val_accuracy: 0.0988 - val_loss: 4.0453 - learning_rate: 1.0000e-04
# Epoch 8/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.0664 - loss: 4.1015 - val_accuracy: 0.1116 - val_loss: 3.9300 - learning_rate: 1.0000e-04
# Epoch 9/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.0740 - loss: 4.0347 - val_accuracy: 0.1258 - val_loss: 3.8428 - learning_rate: 1.0000e-04
# Epoch 10/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.0876 - loss: 3.9289 - val_accuracy: 0.1392 - val_loss: 3.7530 - learning_rate: 1.0000e-04
# Epoch 11/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.1051 - loss: 3.8166 - val_accuracy: 0.1578 - val_loss: 3.6620 - learning_rate: 1.0000e-04
# Epoch 12/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.1203 - loss: 3.6848 - val_accuracy: 0.1608 - val_loss: 3.6424 - learning_rate: 1.0000e-04
# Epoch 13/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.1339 - loss: 3.5776 - val_accuracy: 0.1708 - val_loss: 3.5230 - learning_rate: 1.0000e-04
# Epoch 14/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.1528 - loss: 3.4560 - val_accuracy: 0.1914 - val_loss: 3.4162 - learning_rate: 1.0000e-04
# Epoch 15/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.1749 - loss: 3.3344 - val_accuracy: 0.2056 - val_loss: 3.3510 - learning_rate: 1.0000e-04
# Epoch 16/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.1915 - loss: 3.2201 - val_accuracy: 0.2224 - val_loss: 3.2775 - learning_rate: 1.0000e-04
# Epoch 17/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.2078 - loss: 3.1326 - val_accuracy: 0.2378 - val_loss: 3.1476 - learning_rate: 1.0000e-04
# Epoch 18/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.2254 - loss: 3.0289 - val_accuracy: 0.2466 - val_loss: 3.1017 - learning_rate: 1.0000e-04
# Epoch 19/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 36ms/step - accuracy: 0.2445 - loss: 2.9200 - val_accuracy: 0.2548 - val_loss: 3.0287 - learning_rate: 1.0000e-04
# Epoch 20/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.2658 - loss: 2.8151 - val_accuracy: 0.2606 - val_loss: 2.9971 - learning_rate: 1.0000e-04
# Epoch 21/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.2859 - loss: 2.7256 - val_accuracy: 0.2660 - val_loss: 2.9511 - learning_rate: 1.0000e-04
# Epoch 22/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 36ms/step - accuracy: 0.2996 - loss: 2.6346 - val_accuracy: 0.2734 - val_loss: 2.9065 - learning_rate: 1.0000e-04
# Epoch 23/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.3162 - loss: 2.5665 - val_accuracy: 0.2778 - val_loss: 2.9113 - learning_rate: 1.0000e-04
# Epoch 24/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.3330 - loss: 2.5075 - val_accuracy: 0.2900 - val_loss: 2.8519 - learning_rate: 1.0000e-04
# Epoch 25/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.3495 - loss: 2.4185 - val_accuracy: 0.2878 - val_loss: 2.8791 - learning_rate: 1.0000e-04
# Epoch 26/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 49s 39ms/step - accuracy: 0.3608 - loss: 2.3530 - val_accuracy: 0.2962 - val_loss: 2.8271 - learning_rate: 1.0000e-04
# Epoch 27/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 47s 37ms/step - accuracy: 0.3775 - loss: 2.2855 - val_accuracy: 0.3040 - val_loss: 2.7919 - learning_rate: 1.0000e-04
# Epoch 28/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.3892 - loss: 2.2473 - val_accuracy: 0.3094 - val_loss: 2.7740 - learning_rate: 1.0000e-04
# Epoch 29/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4057 - loss: 2.1660 - val_accuracy: 0.3126 - val_loss: 2.7790 - learning_rate: 1.0000e-04
# Epoch 30/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4129 - loss: 2.1318 - val_accuracy: 0.3124 - val_loss: 2.7962 - learning_rate: 1.0000e-04
# Epoch 31/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4247 - loss: 2.0779 - val_accuracy: 0.3234 - val_loss: 2.7617 - learning_rate: 1.0000e-04
# Epoch 32/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4281 - loss: 2.0593 - val_accuracy: 0.3226 - val_loss: 2.7410 - learning_rate: 1.0000e-04
# Epoch 33/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4429 - loss: 2.0041 - val_accuracy: 0.3226 - val_loss: 2.7611 - learning_rate: 1.0000e-04
# Epoch 34/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4572 - loss: 1.9488 - val_accuracy: 0.3302 - val_loss: 2.7388 - learning_rate: 1.0000e-04
# Epoch 35/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4679 - loss: 1.9049 - val_accuracy: 0.3256 - val_loss: 2.7080 - learning_rate: 1.0000e-04
# Epoch 36/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4719 - loss: 1.8767 - val_accuracy: 0.3376 - val_loss: 2.7715 - learning_rate: 1.0000e-04
# Epoch 37/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4883 - loss: 1.8349 - val_accuracy: 0.3366 - val_loss: 2.7440 - learning_rate: 1.0000e-04
# Epoch 38/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.4958 - loss: 1.7932 - val_accuracy: 0.3410 - val_loss: 2.8275 - learning_rate: 1.0000e-04
# Epoch 39/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.5124 - loss: 1.7195 - val_accuracy: 0.3600 - val_loss: 2.6302 - learning_rate: 2.0000e-05
# Epoch 40/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 49s 39ms/step - accuracy: 0.5212 - loss: 1.6832 - val_accuracy: 0.3598 - val_loss: 2.6337 - learning_rate: 2.0000e-05
# Epoch 41/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.5383 - loss: 1.6111 - val_accuracy: 0.3648 - val_loss: 2.6234 - learning_rate: 2.0000e-05
# Epoch 42/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.5408 - loss: 1.5865 - val_accuracy: 0.3620 - val_loss: 2.6268 - learning_rate: 2.0000e-05
# Epoch 43/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.5445 - loss: 1.5690 - val_accuracy: 0.3680 - val_loss: 2.6700 - learning_rate: 2.0000e-05
# Epoch 44/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.5470 - loss: 1.5511 - val_accuracy: 0.3664 - val_loss: 2.6402 - learning_rate: 2.0000e-05
# Epoch 45/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.5578 - loss: 1.5132 - val_accuracy: 0.3720 - val_loss: 2.6405 - learning_rate: 4.0000e-06
# Epoch 46/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.5617 - loss: 1.4977 - val_accuracy: 0.3676 - val_loss: 2.6335 - learning_rate: 4.0000e-06
